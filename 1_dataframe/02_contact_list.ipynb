# %%
# Exercise 02: Contact List

import pandas as pd

# dictionary named 'contacts'
contacts = {
    'name': ['Mike', 'William', 'Dustin', 'Lucas'],
    'age': [12, 11, 12, 11],
    'phone_number': ['939-555-0113', '939-555-0114', '939-555-0115', '939-555-0116'],
    'astrological_sign': ['Taurus', 'Scorpio', 'Virgo', 'Leo']
}

# dataframe created using 'contacts' dictionary
df = pd.DataFrame(contacts)

df
# Out:
#       name  age  phone_number astrological_sign
# 0     Mike   12  939-555-0113            Taurus
# 1  William   11  939-555-0114           Scorpio
# 2   Dustin   12  939-555-0115             Virgo
# 3    Lucas   11  939-555-0116               Leo
