# %%
# Exercise 07: Review

import pandas as pd

data = {
    'Player': ['Virat Kohli', 'Rajat Patidar', 'Devdutt Padikkal', 'Phil Salt', 'Jitesh Sharma', 'Jordan Cox', 'Tim David', 'Krunal Pandya', 'Venkatesh Iyer', 'Romario Shepherd', 'Josh Hazlewood', 'Bhuvneshwar Kumar', 'Jacob Duffy','Suyash Sharma', 'Rasikh Salam'],
    'Role': ['Batter', 'Batter', 'Batter', 'WK-Batter', 'WK-Batter', 'WK-Batter', 'All-rounder', 'All-rounder', 'All-rounder', 'All-rounder', 'Bowler', 'Bowler', 'Bowler', 'Bowler', 'Bowler'],
    'Matches': [240, 40, 55, 35, 60, 20, 50, 120, 70, 40, 100, 150, 30, 25, 40],
    'Runs': [7600, 1200, 1600, 950, 1500, 500, 1200, 2200, 1800, 600, 200, 300, 100, 50, 80],
    'Wickets': [4, 0, 0, 0, 0, 0, 10, 80, 25, 45, 130, 160, 35, 28, 45],
    'Strike Rate': [130.5, 135.0, 132.0, 140.0, 136.0, 128.0, 150.0, 125.0, 132.0, 135.0, 90.0, 85.0, 88.0, 82.0, 87.0],
    'Average': [38.0, 32.5, 29.0, 27.0, 25.0, 24.0, 26.0, 28.0, 30.0, 22.0, 20.0, 21.0, 19.0, 18.0, 20.0]    
}
sports_player = pd.DataFrame(data)
sports_player

# %%
# Adding a new column 'age'
sports_player['Age'] = [37, 31, 25, 29, 29, 25, 30, 35, 31, 31, 35, 36, 31, 21, 26]

# %%
# Sort by Runs (highest first)
sports_player.sort_values(by='Runs', ascending=False)

# %%
# Filter players who are batters with Runs > 1000 and Strike Rate > 130
filtered_df = sports_player[(sports_player['Role'] == 'Batter') & (sports_player['Runs'] > 1000) & (sports_player['Strike Rate'] > 130)]
filtered_df
